# Out:
#      SalePrice
# 1    169277.1
# 2    187758.4
# 3    183583.7
# 4    179317.5
# 5    150730.1
# 6    177151.0
# 7    172070.7
# 8    175111.0
# 9    162011.7
# 10   160726.2
# 11   157933.3
# 12   145291.2
# 13   159672.0
# 14   164167.5
# 15   150891.6
# 16   179461.0
# 17   185034.6
# 18   182352.2
# 19   183053.5
# 20   187823.3
# 21   186544.1
# 22   158230.8
# 23   190552.8
# 24   147183.7
# 25   185855.3
# 26   174350.5
# 27   201740.6
# 28   162986.4
# 29   162330.2
# 30   165845.9
# ...  ...
# 1430 160515.9
# 1431 192167.6
# 1432 178751.6
# 1433 198678.9
# 1434 164553.1
# 1435 156887.9
# 1436 164185.8
# 1437 212992.1
# 1438 197468.6
# 1439 180106.8
# 1440 183972.1
# 1441 245283.2
# 1442 170352.0
# 1443 195596.3
# 1444 189369.8
# 1445 223667.4
# 1446 169335.3
# 1447 167411.0
# 1448 187709.6
# 1449 196526.0
# 1450 137402.6
# 1451 165086.8
# 1452 188506.4
# 1453 172917.5
# 1454 166274.3
# 1455 167081.2
# 1456 164788.8
# 1457 219222.4
# 1458 184924.3
# 1459 187741.9

# %%
str(data)
# Out:
# 'data.frame':	1459 obs. of  2 variables:
#  $ Id       : int  1461 1462 1463 1464 1465 1466 1467 1468 1469 1470 ...
#  $ SalePrice: num  169277 187758 183584 179317 150730 ...

# %%
summary(data)
# Out:
#        Id         SalePrice
#  Min.   :1461   Min.   :135751
#  1st Qu.:1826   1st Qu.:168703
#  Median :2190   Median :179209
#  Mean   :2190   Mean   :179184
#  3rd Qu.:2554   3rd Qu.:186789
#  Max.   :2919   Max.   :281644

# %%
attach(data)

# %%
install.packages["closure"]
# Out:
# Error in install.packages["closure"]: object of type 'closure' is not subsettable
# Traceback:

# %%
install.packages["jjplot"]
# Out:
# Error in install.packages["jjplot"]: object of type 'closure' is not subsettable
# Traceback:

# %%
library["sjplot"]
# Out:
# Error in library["sjplot"]: object of type 'closure' is not subsettable
# Traceback:

# %%
model = lm(data = data , data$Id~data$SalePrice)

# %%
summary(model)
# Out:
# Call:
# lm(formula = data$Id ~ data$SalePrice, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -807.60 -362.44   -3.18  349.82  854.45
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    1.613e+03  1.193e+02  13.526  < 2e-16 ***
# data$SalePrice 3.218e-03  6.629e-04   4.855 1.34e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 418.1 on 1457 degrees of freedom
# Multiple R-squared:  0.01592,	Adjusted R-squared:  0.01524
# F-statistic: 23.57 on 1 and 1457 DF,  p-value: 1.336e-06

# %%
tab_model(model)
# Out:
# Error in tab_model(model): could not find function "tab_model"
# Traceback:

# %%
plot(data)
# Out:
# plot without title
