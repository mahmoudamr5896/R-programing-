# %%
df = read.csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
df.write.csv('once_csv')
# Out:
# Error in df.write.csv("once_csv"): could not find function "df.write.csv"
# Traceback:

# %%
df
# Out:
#        iso_code continent location    date       total_cases new_cases
# 1      AFG      Asia      Afghanistan 2020-02-24  5           5
# 2      AFG      Asia      Afghanistan 2020-02-25  5           0
# 3      AFG      Asia      Afghanistan 2020-02-26  5           0
# 4      AFG      Asia      Afghanistan 2020-02-27  5           0
# 5      AFG      Asia      Afghanistan 2020-02-28  5           0
# 6      AFG      Asia      Afghanistan 2020-02-29  5           0
# 7      AFG      Asia      Afghanistan 2020-03-01  5           0
# 8      AFG      Asia      Afghanistan 2020-03-02  5           0
# 9      AFG      Asia      Afghanistan 2020-03-03  5           0
# 10     AFG      Asia      Afghanistan 2020-03-04  5           0
# 11     AFG      Asia      Afghanistan 2020-03-05  5           0
# 12     AFG      Asia      Afghanistan 2020-03-06  5           0
# 13     AFG      Asia      Afghanistan 2020-03-07  8           3
# 14     AFG      Asia      Afghanistan 2020-03-08  8           0
# ...

# %%
summary(df)
# Out:
#     iso_code              continent          location              date
#  ARG    :  1053                :13310   Argentina:  1053   2021-08-22:   247
#  MEX    :  1053   Africa       :53608   Mexico   :  1053   2021-08-23:   247
#  THA    :  1050   Asia         :49868   Thailand :  1050   2021-08-24:   247
#  TWN    :  1038   Europe       :54016   Taiwan   :  1038   2021-08-25:   247
#  CHN    :  1032   North America:35613   Asia     :  1032   2021-08-26:   247
#  JPN    :  1032   Oceania      :16638   China    :  1032   2021-08-27:   247
#  (Other):229666   South America:12871   (Other)  :229666   (Other)   :234442
#   total_cases          new_cases       new_cases_smoothed  total_deaths
#  Min.   :        1   Min.   :      0   Min.   :      0    Min.   :      1
#  1st Qu.:     4714   1st Qu.:      0   1st Qu.:      6    1st Qu.:    115
#  Median :    52386   Median :     50   Median :     90    Median :   1225
# ...

# %%
attach(df)

# %%
plot(df['new_cases'])
# Out:
# plot without title
